# %% [markdown]
# ### Билеты для коллоквиума 29 марта
#
# 1. Линейная регрессия. Что такое линейная регрессия и как она работает.
# 2. Функции потерь и метрики. Что такое и чем отличаются.
# 3. Что такое регуляризация в линейной регрессии? L1 и L2 регуляризация.
# 4. Интерпретация коэффициентов линейной регрессии.
# 5. Кодирование признаков. Категориальные признаки. Нормализация и стандартизация данных.
# 6. Метрики для оценки качества линейной регрессии.
# 7. Что такое линейная классификация? Чем она отличается от линейной регрессии?
# 8. Метрики для оценки качества классификации.
# 9. Этапы предобработки текста. Стемминг, токенизация, лемматизация и проч.
# 10. Bag of Words (BoW).
# 11. TF-IDF.
# 12. One-Hot Encoding.
# 13. Кластеризация. Алгоритм k-средних
# 14. Кластеризация. Иерархическая кластеризация.
# 15. Кластеризация. DBSCAN и HDBSCAN.
# 16. Метрики кластеризации.
# 17. Меры близости в векторном пространстве.
